# %%
import pandas as pd

# %%
df = pd.read_csv("CreditCardData.csv")

# %%
df.head(20)
# Out:
#    Transaction ID       Date Day of Week  Time Type of Card Entry Mode Amount  \
# 0       #3577 209  14-Oct-20   Wednesday    19         Visa        Tap     £5
# 1       #3039 221  14-Oct-20   Wednesday    17   MasterCard        PIN   £288
# 2       #2694 780  14-Oct-20   Wednesday    14         Visa        Tap     £5
# 3       #2640 960  13-Oct-20     Tuesday    14         Visa        Tap    £28
# 4       #2771 031  13-Oct-20     Tuesday    23         Visa        CVC    £91
# 5       #3446 698  13-Oct-20     Tuesday    20   MasterCard        Tap    £30
# 6       #3652 191  13-Oct-20     Tuesday    18         Visa        CVC   £231
# 7       #3161 927  13-Oct-20     Tuesday    18   MasterCard        CVC   £154
# 8       #3025 809  13-Oct-20     Tuesday    23   MasterCard        PIN    £39
# 9       #3413 696  14-Oct-20   Wednesday    23   MasterCard        Tap    £17
# 10      #2667 502  13-Oct-20     Tuesday    11         Visa        PIN   £326
# 11      #3474 192  14-Oct-20   Wednesday     1   MasterCard        PIN   £106
# 12      #3328 082  13-Oct-20     Tuesday    21   MasterCard        PIN    £21
# 13      #3409 035  13-Oct-20     Tuesday    20   MasterCard        PIN   £211
# 14      #2605 734  13-Oct-20     Tuesday    11         Visa        Tap    £28
# 15      #3261 845  14-Oct-20   Wednesday    17   MasterCard        PIN    £98
# 16      #3513 029  13-Oct-20     Tuesday     0   MasterCard        CVC    £25
# 17      #3173 400  14-Oct-20   Wednesday    21         Visa        CVC   £242
# 18      #2688 254  13-Oct-20     Tuesday    20         Visa        PIN    £22
# 19      #3521 688  14-Oct-20   Wednesday    23   MasterCard        Tap    £29
#
#    Type of Transaction Merchant Group Country of Transaction Shipping Address  \
# 0                  POS  Entertainment         United Kingdom   United Kingdom
# 1                  POS       Services                    USA              USA
# 2                  POS     Restaurant                  India            India
# 3                  POS  Entertainment         United Kingdom            India
# 4               Online    Electronics                    USA              USA
# 5                  POS       Children                  India            India
# 6               Online       Children         United Kingdom   United Kingdom
# 7               Online       Services                    USA              USA
# 8                  ATM        Fashion                 Russia           Russia
# 9                  POS  Entertainment                  India            India
# 10                 ATM       Children         United Kingdom   United Kingdom
# 11                 POS        Fashion                 Russia           Russia
# 12                 ATM     Restaurant         United Kingdom   United Kingdom
# 13                 ATM           Food         United Kingdom   United Kingdom
# 14                 POS  Entertainment         United Kingdom            China
# 15                 ATM       Products         United Kingdom   United Kingdom
# 16              Online           Food                 Russia           Russia
# 17              Online       Services         United Kingdom   United Kingdom
# 18                 ATM       Children         United Kingdom   United Kingdom
# 19                 POS       Products                  India            India
#
#    Country of Residence Gender   Age      Bank  Fraud
# 0        United Kingdom      M  25.2       RBS      0
# 1                   USA      F  49.6    Lloyds      0
# 2                 India      F  42.2  Barclays      0
# 3        United Kingdom      F  51.0  Barclays      0
# 4        United Kingdom      M  38.0   Halifax      1
# 5                 India      M  48.4     Monzo      0
# 6        United Kingdom      M  39.5  Barclays      0
# 7        United Kingdom      M  37.8      HSBC      0
# 8        United Kingdom      F  43.3     Metro      0
# 9                 India      M  69.9  Barlcays      0
# 10       United Kingdom      F  54.8     Metro      0
# 11       United Kingdom      F  48.7     Metro      1
# 12       United Kingdom      M  43.6  Barclays      0
# 13       United Kingdom      F  46.4      HSBC      0
# 14       United Kingdom      F  50.6     Metro      0
# 15       United Kingdom      F  37.2     Monzo      0
# 16       United Kingdom      M  54.3  Barlcays      1
# 17       United Kingdom      M  62.0  Barlcays      0
# 18       United Kingdom      M  28.5    Lloyds      0
# 19       United Kingdom      F  55.0   Halifax      0

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Fill missing values in the 'Merchant Group' column with a placeholder
df['Merchant Group'].fillna('Unknown', inplace=True)

# Filter top 2000 records
df_top_2000 = df.head(2000)

# Filter transactions with merchant group 'Entertainment'
entertainment_transactions = df_top_2000[df_top_2000['Merchant Group'] == 'Entertainment']
df_top_2000
# Out:
#      Transaction ID       Date Day of Week  Time Type of Card Entry Mode  \
# 0         #3577 209  14-Oct-20   Wednesday    19         Visa        Tap
# 1         #3039 221  14-Oct-20   Wednesday    17   MasterCard        PIN
# 2         #2694 780  14-Oct-20   Wednesday    14         Visa        Tap
# 3         #2640 960  13-Oct-20     Tuesday    14         Visa        Tap
# 4         #2771 031  13-Oct-20     Tuesday    23         Visa        CVC
# ...             ...        ...         ...   ...          ...        ...
# 1995      #2687 300  14-Oct-20   Wednesday    23   MasterCard        PIN
# 1996      #2867 705  14-Oct-20   Wednesday    23         Visa        PIN
# 1997      #2988 629  14-Oct-20   Wednesday    10         Visa        Tap
# 1998      #2635 065  14-Oct-20   Wednesday    19         Visa        PIN
# 1999      #3230 144  13-Oct-20     Tuesday    21         Visa        PIN
#
#      Amount Type of Transaction Merchant Group Country of Transaction  \
# 0        £5                 POS  Entertainment         United Kingdom
# 1      £288                 POS       Services                    USA
# 2        £5                 POS     Restaurant                  India
# 3       £28                 POS  Entertainment         United Kingdom
# 4       £91              Online    Electronics                    USA
# ...     ...                 ...            ...                    ...
# 1995    £21                 ATM       Products                  China
# 1996    £22                 ATM    Electronics         United Kingdom
# 1997     £9                 POS       Products         United Kingdom
# 1998    £22                 ATM   Subscription                    USA
# 1999   £230                 ATM         Gaming         United Kingdom
#
#      Shipping Address Country of Residence Gender   Age      Bank  Fraud
# 0      United Kingdom       United Kingdom      M  25.2       RBS      0
# 1                 USA                  USA      F  49.6    Lloyds      0
# 2               India                India      F  42.2  Barclays      0
# 3               India       United Kingdom      F  51.0  Barclays      0
# 4                 USA       United Kingdom      M  38.0   Halifax      1
# ...               ...                  ...    ...   ...       ...    ...
# 1995            China                China      F  39.6   Halifax      0
# 1996   United Kingdom       United Kingdom      M  47.1  Barlcays      0
# 1997   United Kingdom       United Kingdom      F  32.3  Barclays      0
# 1998   United Kingdom                  USA      F  58.6  Barclays      0
# 1999            India       United Kingdom      M  35.5       RBS      0
#
# [2000 rows x 16 columns]

# %%
# Vectorize the text data
vectorizer = TfidfVectorizer()
merchant_group_vectors = vectorizer.fit_transform(df_top_2000['Merchant Group'])

# Calculate cosine similarity
cosine_sim = cosine_similarity(merchant_group_vectors, merchant_group_vectors)

# Get indices of 'Entertainment' transactions
entertainment_indices = entertainment_transactions.index

# Find similar transactions
similar_transactions = []
for idx in entertainment_indices:
    similarity_scores = list(enumerate(cosine_sim[idx]))
    similarity_scores_sorted = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
    similar_indices = [x[0] for x in similarity_scores_sorted[1:11]]  # Exclude the transaction itself
    similar_transactions.extend(similar_indices)

# %%
# Remove duplicate indices and keep only unique ones
similar_transactions = list(set(similar_transactions))

# Print details of similar transactions
print("10 similar transactions based on merchant group 'Entertainment':")
for idx in similar_transactions:
    print(df_top_2000.iloc[idx])
# Out:
# 10 similar transactions based on merchant group 'Entertainment':
# Transaction ID                 #2973 712
# Date                           14-Oct-20
# Day of Week                    Wednesday
# Time                                  13
# Type of Card                  MasterCard
# Entry Mode                           CVC
# Amount                              £296
# Type of Transaction               Online
# Merchant Group             Entertainment
# Country of Transaction    United Kingdom
# Shipping Address          United Kingdom
# Country of Residence      United Kingdom
# Gender                                 F
# Age                                 41.8
# Bank                            Barlcays
# Fraud                                  0
# Name: 65, dtype: object
# Transaction ID                 #2640 960
# Date                           13-Oct-20
# Day of Week                      Tuesday
# Time                                  14
# Type of Card                        Visa
# Entry Mode                           Tap
# Amount                               £28
# Type of Transaction                  POS
# Merchant Group             Entertainment
# Country of Transaction    United Kingdom
# Shipping Address                   India
# Country of Residence      United Kingdom
# Gender                                 F
# Age                                 51.0
# Bank                            Barclays
# Fraud                                  0
# Name: 3, dtype: object
# Transaction ID                 #2675 985
# Date                           14-Oct-20
# Day of Week                    Wednesday
# Time                                   9
# Type of Card                  MasterCard
# Entry Mode                           PIN
# Amount                               £21
# Type of Transaction                  ATM
# Merchant Group             Entertainment
# Country of Transaction    United Kingdom
# Shipping Address          United Kingdom
# Country of Residence      United Kingdom
# Gender                                 F
# Age                                 58.7
# Bank                             Halifax
# Fraud                                  0
# Name: 70, dtype: object
# Transaction ID                 #2784 622
# Date                           14-Oct-20
# Day of Week                    Wednesday
# Time                                   3
# Type of Card                  MasterCard
# Entry Mode                           CVC
# Amount                               £22
# Type of Transaction               Online
# Merchant Group             Entertainment
# Country of Transaction            Russia
# Shipping Address                  Russia
# Country of Residence      United Kingdom
# Gender                                 M
# Age                                 57.7
# Bank                             Halifax
# Fraud                                  1
# Name: 103, dtype: object
# Transaction ID                #3413 696
# Date                          14-Oct-20
# Day of Week                   Wednesday
# Time                                 23
# Type of Card                 MasterCard
# Entry Mode                          Tap
# Amount                              £17
# Type of Transaction                 POS
# Merchant Group            Entertainment
# Country of Transaction            India
# Shipping Address                  India
# Country of Residence              India
# Gender                                M
# Age                                69.9
# Bank                           Barlcays
# Fraud                                 0
# Name: 9, dtype: object
# Transaction ID                 #2605 734
# Date                           13-Oct-20
# Day of Week                      Tuesday
# Time                                  11
# Type of Card                        Visa
# Entry Mode                           Tap
# Amount                               £28
# Type of Transaction                  POS
# Merchant Group             Entertainment
# Country of Transaction    United Kingdom
# Shipping Address                   China
# Country of Residence      United Kingdom
# Gender                                 F
# Age                                 50.6
# Bank                               Metro
# Fraud                                  0
# Name: 14, dtype: object
# Transaction ID                 #3032 120
# Date                           14-Oct-20
# Day of Week                    Wednesday
# Time                                   8
# Type of Card                  MasterCard
# Entry Mode                           PIN
# Amount                              £285
# Type of Transaction                  POS
# Merchant Group             Entertainment
# Country of Transaction               USA
# Shipping Address                     USA
# Country of Residence      United Kingdom
# Gender                                 M
# Age                                 51.2
# Bank                                HSBC
# Fraud                                  0
# Name: 53, dtype: object
# Transaction ID                 #2980 181
# Date                           14-Oct-20
# Day of Week                    Wednesday
# Time                                   9
# Type of Card                  MasterCard
# Entry Mode                           CVC
# Amount                              £155
# Type of Transaction               Online
# Merchant Group             Entertainment
# Country of Transaction    United Kingdom
# Shipping Address          United Kingdom
# Country of Residence      United Kingdom
# Gender                                 M
# Age                                 58.4
# Bank                             Halifax
# Fraud                                  0
# Name: 24, dtype: object
# Transaction ID                #3639 210
# Date                          14-Oct-20
# Day of Week                   Wednesday
# Time                                  9
# Type of Card                 MasterCard
# Entry Mode                          CVC
# Amount                              £12
# Type of Transaction              Online
# Merchant Group            Entertainment
# Country of Transaction              USA
# Shipping Address                    USA
# Country of Residence                USA
# Gender                                M
# Age                                45.6
# Bank                              Monzo
# Fraud                                 0
# Name: 57, dtype: object
# Transaction ID                 #3382 956
# Date                           14-Oct-20
# Day of Week                    Wednesday
# Time                                  15
# Type of Card                        Visa
# Entry Mode                           PIN
# Amount                               £30
# Type of Transaction                  ATM
# Merchant Group             Entertainment
# Country of Transaction    United Kingdom
# Shipping Address          United Kingdom
# Country of Residence      United Kingdom
# Gender                                 M
# Age                                 45.1
# Bank                            Barclays
# Fraud                                  0
# Name: 29, dtype: object

# %%
# Fill missing values in the 'Entry Mode' column with a placeholder
df['Entry Mode'].fillna('Unknown', inplace=True)

# Filter top 2000 records
df_top_2000 = df.head(2000)

# Filter transactions with merchant group 'CVC'
cvc_transactions = df_top_2000[df_top_2000['Entry Mode'] == 'CVC']
df_top_2000
# Out:
#      Transaction ID       Date Day of Week  Time Type of Card Entry Mode  \
# 0         #3577 209  14-Oct-20   Wednesday    19         Visa        Tap
# 1         #3039 221  14-Oct-20   Wednesday    17   MasterCard        PIN
# 2         #2694 780  14-Oct-20   Wednesday    14         Visa        Tap
# 3         #2640 960  13-Oct-20     Tuesday    14         Visa        Tap
# 4         #2771 031  13-Oct-20     Tuesday    23         Visa        CVC
# ...             ...        ...         ...   ...          ...        ...
# 1995      #2687 300  14-Oct-20   Wednesday    23   MasterCard        PIN
# 1996      #2867 705  14-Oct-20   Wednesday    23         Visa        PIN
# 1997      #2988 629  14-Oct-20   Wednesday    10         Visa        Tap
# 1998      #2635 065  14-Oct-20   Wednesday    19         Visa        PIN
# 1999      #3230 144  13-Oct-20     Tuesday    21         Visa        PIN
#
#      Amount Type of Transaction Merchant Group Country of Transaction  \
# 0        £5                 POS  Entertainment         United Kingdom
# 1      £288                 POS       Services                    USA
# 2        £5                 POS     Restaurant                  India
# 3       £28                 POS  Entertainment         United Kingdom
# 4       £91              Online    Electronics                    USA
# ...     ...                 ...            ...                    ...
# 1995    £21                 ATM       Products                  China
# 1996    £22                 ATM    Electronics         United Kingdom
# 1997     £9                 POS       Products         United Kingdom
# 1998    £22                 ATM   Subscription                    USA
# 1999   £230                 ATM         Gaming         United Kingdom
#
#      Shipping Address Country of Residence Gender   Age      Bank  Fraud
# 0      United Kingdom       United Kingdom      M  25.2       RBS      0
# 1                 USA                  USA      F  49.6    Lloyds      0
# 2               India                India      F  42.2  Barclays      0
# 3               India       United Kingdom      F  51.0  Barclays      0
# 4                 USA       United Kingdom      M  38.0   Halifax      1
# ...               ...                  ...    ...   ...       ...    ...
# 1995            China                China      F  39.6   Halifax      0
# 1996   United Kingdom       United Kingdom      M  47.1  Barlcays      0
# 1997   United Kingdom       United Kingdom      F  32.3  Barclays      0
# 1998   United Kingdom                  USA      F  58.6  Barclays      0
# 1999            India       United Kingdom      M  35.5       RBS      0
#
# [2000 rows x 16 columns]

# %%
# Vectorize the text data
vectorizer = TfidfVectorizer()
entry_group_vectors = vectorizer.fit_transform(df_top_2000['Entry Mode'])

# Calculate cosine similarity
cosine_sim = cosine_similarity(entry_group_vectors, entry_group_vectors)

# Get indices of 'CVC' transactions
cvc_indices = cvc_transactions.index

# Find similar transactions
similar_transactions = []
for idx in cvc_indices:
    similarity_scores = list(enumerate(cosine_sim[idx]))
    similarity_scores_sorted = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
    similar_indices = [x[0] for x in similarity_scores_sorted[1:11]]  # Exclude the transaction itself
    similar_transactions.extend(similar_indices)

# %%
# Remove duplicate indices and keep only unique ones
similar_transactions = list(set(similar_transactions))

# Print details of similar transactions
print("10 similar transactions based on a credit/debit entry mode 'CVC':")
for idx in similar_transactions:
    print(df_top_2000.iloc[idx])
# Out:
# 10 similar transactions based on a credit/debit entry mode 'CVC':
# Transaction ID                 #3652 191
# Date                           13-Oct-20
# Day of Week                      Tuesday
# Time                                  18
# Type of Card                        Visa
# Entry Mode                           CVC
# Amount                              £231
# Type of Transaction               Online
# Merchant Group                  Children
# Country of Transaction    United Kingdom
# Shipping Address          United Kingdom
# Country of Residence      United Kingdom
# Gender                                 M
# Age                                 39.5
# Bank                            Barclays
# Fraud                                  0
# Name: 6, dtype: object
# Transaction ID                 #3161 927
# Date                           13-Oct-20
# Day of Week                      Tuesday
# Time                                  18
# Type of Card                  MasterCard
# Entry Mode                           CVC
# Amount                              £154
# Type of Transaction               Online
# Merchant Group                  Services
# Country of Transaction               USA
# Shipping Address                     USA
# Country of Residence      United Kingdom
# Gender                                 M
# Age                                 37.8
# Bank                                HSBC
# Fraud                                  0
# Name: 7, dtype: object
# Transaction ID                 #3513 029
# Date                           13-Oct-20
# Day of Week                      Tuesday
# Time                                   0
# Type of Card                  MasterCard
# Entry Mode                           CVC
# Amount                               £25
# Type of Transaction               Online
# Merchant Group                      Food
# Country of Transaction            Russia
# Shipping Address                  Russia
# Country of Residence      United Kingdom
# Gender                                 M
# Age                                 54.3
# Bank                            Barlcays
# Fraud                                  1
# Name: 16, dtype: object
# Transaction ID                 #3173 400
# Date                           14-Oct-20
# Day of Week                    Wednesday
# Time                                  21
# Type of Card                        Visa
# Entry Mode                           CVC
# Amount                              £242
# Type of Transaction               Online
# Merchant Group                  Services
# Country of Transaction    United Kingdom
# Shipping Address          United Kingdom
# Country of Residence      United Kingdom
# Gender                                 M
# Age                                 62.0
# Bank                            Barlcays
# Fraud                                  0
# Name: 17, dtype: object
# Transaction ID                 #2624 152
# Date                           13-Oct-20
# Day of Week                      Tuesday
# Time                                   8
# Type of Card                        Visa
# Entry Mode                           CVC
# Amount                              £397
# Type of Transaction               Online
# Merchant Group               Electronics
# Country of Transaction    United Kingdom
# Shipping Address          United Kingdom
# Country of Residence      United Kingdom
# Gender                                 F
# Age                                 29.9
# Bank                            Barclays
# Fraud                                  0
# Name: 20, dtype: object
# Transaction ID            #3498 300
# Date                      13-Oct-20
# Day of Week                 Tuesday
# Time                             19
# Type of Card                   Visa
# Entry Mode                      CVC
# Amount                          £38
# Type of Transaction          Online
# Merchant Group                 Food
# Country of Transaction       Russia
# Shipping Address             Russia
# Country of Residence         Russia
# Gender                            M
# Age                            80.5
# Bank                       Barlcays
# Fraud                             0
# Name: 21, dtype: object
# Transaction ID                 #2980 181
# Date                           14-Oct-20
# Day of Week                    Wednesday
# Time                                   9
# Type of Card                  MasterCard
# Entry Mode                           CVC
# Amount                              £155
# Type of Transaction               Online
# Merchant Group             Entertainment
# Country of Transaction    United Kingdom
# Shipping Address          United Kingdom
# Country of Residence      United Kingdom
# Gender                                 M
# Age                                 58.4
# Bank                             Halifax
# Fraud                                  0
# Name: 24, dtype: object
# Transaction ID            #2788 277
# Date                      14-Oct-20
# Day of Week               Wednesday
# Time                              9
# Type of Card                   Visa
# Entry Mode                      CVC
# Amount                          £12
# Type of Transaction          Online
# Merchant Group             Children
# Country of Transaction        China
# Shipping Address              China
# Country of Residence          China
# Gender                            M
# Age                            47.2
# Bank                       Barclays
# Fraud                             0
# Name: 25, dtype: object
# Transaction ID                 #3355 723
# Date                           13-Oct-20
# Day of Week                      Tuesday
# Time                                  17
# Type of Card                        Visa
# Entry Mode                           CVC
# Amount                              £381
# Type of Transaction               Online
# Merchant Group                      Food
# Country of Transaction    United Kingdom
# Shipping Address                     USA
# Country of Residence      United Kingdom
# Gender                                 F
# Age                                 42.4
# Bank                               Monzo
# Fraud                                  0
# Name: 27, dtype: object
# Transaction ID                 #3435 814
# Date                           13-Oct-20
# Day of Week                      Tuesday
# Time                                  22
# Type of Card                  MasterCard
# Entry Mode                           CVC
# Amount                              £397
# Type of Transaction               Online
# Merchant Group                Restaurant
# Country of Transaction    United Kingdom
# Shipping Address          United Kingdom
# Country of Residence      United Kingdom
# Gender                                 F
# Age                                 53.3
# Bank                               Metro
# Fraud                                  0
# Name: 30, dtype: object

# %%
# Fill missing values in the 'Type of Transaction' column with a placeholder
df['Type of Transaction'].fillna('Unknown', inplace=True)

# Filter top 2000 records
df_top_2000 = df.head(2000)

# Filter transactions with type of transaction 'Online'
online_transactions = df_top_2000[df_top_2000['Type of Transaction'] == 'Online']
df_top_2000
# Out:
#      Transaction ID       Date Day of Week  Time Type of Card Entry Mode  \
# 0         #3577 209  14-Oct-20   Wednesday    19         Visa        Tap
# 1         #3039 221  14-Oct-20   Wednesday    17   MasterCard        PIN
# 2         #2694 780  14-Oct-20   Wednesday    14         Visa        Tap
# 3         #2640 960  13-Oct-20     Tuesday    14         Visa        Tap
# 4         #2771 031  13-Oct-20     Tuesday    23         Visa        CVC
# ...             ...        ...         ...   ...          ...        ...
# 1995      #2687 300  14-Oct-20   Wednesday    23   MasterCard        PIN
# 1996      #2867 705  14-Oct-20   Wednesday    23         Visa        PIN
# 1997      #2988 629  14-Oct-20   Wednesday    10         Visa        Tap
# 1998      #2635 065  14-Oct-20   Wednesday    19         Visa        PIN
# 1999      #3230 144  13-Oct-20     Tuesday    21         Visa        PIN
#
#      Amount Type of Transaction Merchant Group Country of Transaction  \
# 0        £5                 POS  Entertainment         United Kingdom
# 1      £288                 POS       Services                    USA
# 2        £5                 POS     Restaurant                  India
# 3       £28                 POS  Entertainment         United Kingdom
# 4       £91              Online    Electronics                    USA
# ...     ...                 ...            ...                    ...
# 1995    £21                 ATM       Products                  China
# 1996    £22                 ATM    Electronics         United Kingdom
# 1997     £9                 POS       Products         United Kingdom
# 1998    £22                 ATM   Subscription                    USA
# 1999   £230                 ATM         Gaming         United Kingdom
#
#      Shipping Address Country of Residence Gender   Age      Bank  Fraud
# 0      United Kingdom       United Kingdom      M  25.2       RBS      0
# 1                 USA                  USA      F  49.6    Lloyds      0
# 2               India                India      F  42.2  Barclays      0
# 3               India       United Kingdom      F  51.0  Barclays      0
# 4                 USA       United Kingdom      M  38.0   Halifax      1
# ...               ...                  ...    ...   ...       ...    ...
# 1995            China                China      F  39.6   Halifax      0
# 1996   United Kingdom       United Kingdom      M  47.1  Barlcays      0
# 1997   United Kingdom       United Kingdom      F  32.3  Barclays      0
# 1998   United Kingdom                  USA      F  58.6  Barclays      0
# 1999            India       United Kingdom      M  35.5       RBS      0
#
# [2000 rows x 16 columns]

# %%
# Vectorize the text data
vectorizer = TfidfVectorizer()
transaction_group_vectors = vectorizer.fit_transform(df_top_2000['Type of Transaction'])

# Calculate cosine similarity
cosine_sim = cosine_similarity(transaction_group_vectors, transaction_group_vectors)

# Get indices of 'Online' transactions
online_indices = online_transactions.index

# Find similar transactions
similar_transactions = []
for idx in online_indices:
    similarity_scores = list(enumerate(cosine_sim[idx]))
    similarity_scores_sorted = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
    similar_indices = [x[0] for x in similarity_scores_sorted[1:11]]  # Exclude the transaction itself
    similar_transactions.extend(similar_indices)

# %%
# Remove duplicate indices and keep only unique ones
similar_transactions = list(set(similar_transactions))

# Print details of similar transactions
print("10 similar transactions based on the type of transaction 'Online':")
for idx in similar_transactions:
    print(df_top_2000.iloc[idx])
# Out:
# 10 similar transactions based on the type of transaction 'Online':
# Transaction ID                 #3652 191
# Date                           13-Oct-20
# Day of Week                      Tuesday
# Time                                  18
# Type of Card                        Visa
# Entry Mode                           CVC
# Amount                              £231
# Type of Transaction               Online
# Merchant Group                  Children
# Country of Transaction    United Kingdom
# Shipping Address          United Kingdom
# Country of Residence      United Kingdom
# Gender                                 M
# Age                                 39.5
# Bank                            Barclays
# Fraud                                  0
# Name: 6, dtype: object
# Transaction ID                 #3161 927
# Date                           13-Oct-20
# Day of Week                      Tuesday
# Time                                  18
# Type of Card                  MasterCard
# Entry Mode                           CVC
# Amount                              £154
# Type of Transaction               Online
# Merchant Group                  Services
# Country of Transaction               USA
# Shipping Address                     USA
# Country of Residence      United Kingdom
# Gender                                 M
# Age                                 37.8
# Bank                                HSBC
# Fraud                                  0
# Name: 7, dtype: object
# Transaction ID                 #3513 029
# Date                           13-Oct-20
# Day of Week                      Tuesday
# Time                                   0
# Type of Card                  MasterCard
# Entry Mode                           CVC
# Amount                               £25
# Type of Transaction               Online
# Merchant Group                      Food
# Country of Transaction            Russia
# Shipping Address                  Russia
# Country of Residence      United Kingdom
# Gender                                 M
# Age                                 54.3
# Bank                            Barlcays
# Fraud                                  1
# Name: 16, dtype: object
# Transaction ID                 #3173 400
# Date                           14-Oct-20
# Day of Week                    Wednesday
# Time                                  21
# Type of Card                        Visa
# Entry Mode                           CVC
# Amount                              £242
# Type of Transaction               Online
# Merchant Group                  Services
# Country of Transaction    United Kingdom
# Shipping Address          United Kingdom
# Country of Residence      United Kingdom
# Gender                                 M
# Age                                 62.0
# Bank                            Barlcays
# Fraud                                  0
# Name: 17, dtype: object
# Transaction ID                 #2624 152
# Date                           13-Oct-20
# Day of Week                      Tuesday
# Time                                   8
# Type of Card                        Visa
# Entry Mode                           CVC
# Amount                              £397
# Type of Transaction               Online
# Merchant Group               Electronics
# Country of Transaction    United Kingdom
# Shipping Address          United Kingdom
# Country of Residence      United Kingdom
# Gender                                 F
# Age                                 29.9
# Bank                            Barclays
# Fraud                                  0
# Name: 20, dtype: object
# Transaction ID            #3498 300
# Date                      13-Oct-20
# Day of Week                 Tuesday
# Time                             19
# Type of Card                   Visa
# Entry Mode                      CVC
# Amount                          £38
# Type of Transaction          Online
# Merchant Group                 Food
# Country of Transaction       Russia
# Shipping Address             Russia
# Country of Residence         Russia
# Gender                            M
# Age                            80.5
# Bank                       Barlcays
# Fraud                             0
# Name: 21, dtype: object
# Transaction ID                 #2980 181
# Date                           14-Oct-20
# Day of Week                    Wednesday
# Time                                   9
# Type of Card                  MasterCard
# Entry Mode                           CVC
# Amount                              £155
# Type of Transaction               Online
# Merchant Group             Entertainment
# Country of Transaction    United Kingdom
# Shipping Address          United Kingdom
# Country of Residence      United Kingdom
# Gender                                 M
# Age                                 58.4
# Bank                             Halifax
# Fraud                                  0
# Name: 24, dtype: object
# Transaction ID            #2788 277
# Date                      14-Oct-20
# Day of Week               Wednesday
# Time                              9
# Type of Card                   Visa
# Entry Mode                      CVC
# Amount                          £12
# Type of Transaction          Online
# Merchant Group             Children
# Country of Transaction        China
# Shipping Address              China
# Country of Residence          China
# Gender                            M
# Age                            47.2
# Bank                       Barclays
# Fraud                             0
# Name: 25, dtype: object
# Transaction ID                 #3355 723
# Date                           13-Oct-20
# Day of Week                      Tuesday
# Time                                  17
# Type of Card                        Visa
# Entry Mode                           CVC
# Amount                              £381
# Type of Transaction               Online
# Merchant Group                      Food
# Country of Transaction    United Kingdom
# Shipping Address                     USA
# Country of Residence      United Kingdom
# Gender                                 F
# Age                                 42.4
# Bank                               Monzo
# Fraud                                  0
# Name: 27, dtype: object
# Transaction ID                 #3435 814
# Date                           13-Oct-20
# Day of Week                      Tuesday
# Time                                  22
# Type of Card                  MasterCard
# Entry Mode                           CVC
# Amount                              £397
# Type of Transaction               Online
# Merchant Group                Restaurant
# Country of Transaction    United Kingdom
# Shipping Address          United Kingdom
# Country of Residence      United Kingdom
# Gender                                 F
# Age                                 53.3
# Bank                               Metro
# Fraud                                  0
# Name: 30, dtype: object

# %%
# Fill missing values in the 'Type of Transaction' column with a placeholder
df['Type of Card'].fillna('Unknown', inplace=True)

# Filter top 2000 records
df_top_2000 = df.head(2000)

# Filter transactions with type of transaction 'Online'
card_transactions = df_top_2000[df_top_2000['Type of Card'] == 'MasterCard']
df_top_2000
# Out:
#      Transaction ID       Date Day of Week  Time Type of Card Entry Mode  \
# 0         #3577 209  14-Oct-20   Wednesday    19         Visa        Tap
# 1         #3039 221  14-Oct-20   Wednesday    17   MasterCard        PIN
# 2         #2694 780  14-Oct-20   Wednesday    14         Visa        Tap
# 3         #2640 960  13-Oct-20     Tuesday    14         Visa        Tap
# 4         #2771 031  13-Oct-20     Tuesday    23         Visa        CVC
# ...             ...        ...         ...   ...          ...        ...
# 1995      #2687 300  14-Oct-20   Wednesday    23   MasterCard        PIN
# 1996      #2867 705  14-Oct-20   Wednesday    23         Visa        PIN
# 1997      #2988 629  14-Oct-20   Wednesday    10         Visa        Tap
# 1998      #2635 065  14-Oct-20   Wednesday    19         Visa        PIN
# 1999      #3230 144  13-Oct-20     Tuesday    21         Visa        PIN
#
#      Amount Type of Transaction Merchant Group Country of Transaction  \
# 0        £5                 POS  Entertainment         United Kingdom
# 1      £288                 POS       Services                    USA
# 2        £5                 POS     Restaurant                  India
# 3       £28                 POS  Entertainment         United Kingdom
# 4       £91              Online    Electronics                    USA
# ...     ...                 ...            ...                    ...
# 1995    £21                 ATM       Products                  China
# 1996    £22                 ATM    Electronics         United Kingdom
# 1997     £9                 POS       Products         United Kingdom
# 1998    £22                 ATM   Subscription                    USA
# 1999   £230                 ATM         Gaming         United Kingdom
#
#      Shipping Address Country of Residence Gender   Age      Bank  Fraud
# 0      United Kingdom       United Kingdom      M  25.2       RBS      0
# 1                 USA                  USA      F  49.6    Lloyds      0
# 2               India                India      F  42.2  Barclays      0
# 3               India       United Kingdom      F  51.0  Barclays      0
# 4                 USA       United Kingdom      M  38.0   Halifax      1
# ...               ...                  ...    ...   ...       ...    ...
# 1995            China                China      F  39.6   Halifax      0
# 1996   United Kingdom       United Kingdom      M  47.1  Barlcays      0
# 1997   United Kingdom       United Kingdom      F  32.3  Barclays      0
# 1998   United Kingdom                  USA      F  58.6  Barclays      0
# 1999            India       United Kingdom      M  35.5       RBS      0
#
# [2000 rows x 16 columns]

# %%
# Vectorize the text data
vectorizer = TfidfVectorizer()
card_group_vectors = vectorizer.fit_transform(df_top_2000['Type of Card'])

# Calculate cosine similarity
cosine_sim = cosine_similarity(card_group_vectors, card_group_vectors)

# Get indices of 'MasterCard' transactions
card_indices = card_transactions.index

# Find similar transactions
similar_transactions = []
for idx in card_indices:
    similarity_scores = list(enumerate(cosine_sim[idx]))
    similarity_scores_sorted = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
    similar_indices = [x[0] for x in similarity_scores_sorted[1:11]]  # Exclude the transaction itself
    similar_transactions.extend(similar_indices)

# %%
# Remove duplicate indices and keep only unique ones
similar_transactions = list(set(similar_transactions))

# Print details of similar transactions
print("10 similar transactions based on the type of card 'MasterCard':")
for idx in similar_transactions:
    print(df_top_2000.iloc[idx])
# Out:
# 10 similar transactions based on the type of card 'MasterCard':
# Transaction ID             #3446 698
# Date                       13-Oct-20
# Day of Week                  Tuesday
# Time                              20
# Type of Card              MasterCard
# Entry Mode                       Tap
# Amount                           £30
# Type of Transaction              POS
# Merchant Group              Children
# Country of Transaction         India
# Shipping Address               India
# Country of Residence           India
# Gender                             M
# Age                             48.4
# Bank                           Monzo
# Fraud                              0
# Name: 5, dtype: object
# Transaction ID                 #3161 927
# Date                           13-Oct-20
# Day of Week                      Tuesday
# Time                                  18
# Type of Card                  MasterCard
# Entry Mode                           CVC
# Amount                              £154
# Type of Transaction               Online
# Merchant Group                  Services
# Country of Transaction               USA
# Shipping Address                     USA
# Country of Residence      United Kingdom
# Gender                                 M
# Age                                 37.8
# Bank                                HSBC
# Fraud                                  0
# Name: 7, dtype: object
# Transaction ID                 #3025 809
# Date                           13-Oct-20
# Day of Week                      Tuesday
# Time                                  23
# Type of Card                  MasterCard
# Entry Mode                           PIN
# Amount                               £39
# Type of Transaction                  ATM
# Merchant Group                   Fashion
# Country of Transaction            Russia
# Shipping Address                  Russia
# Country of Residence      United Kingdom
# Gender                                 F
# Age                                 43.3
# Bank                               Metro
# Fraud                                  0
# Name: 8, dtype: object
# Transaction ID                #3413 696
# Date                          14-Oct-20
# Day of Week                   Wednesday
# Time                                 23
# Type of Card                 MasterCard
# Entry Mode                          Tap
# Amount                              £17
# Type of Transaction                 POS
# Merchant Group            Entertainment
# Country of Transaction            India
# Shipping Address                  India
# Country of Residence              India
# Gender                                M
# Age                                69.9
# Bank                           Barlcays
# Fraud                                 0
# Name: 9, dtype: object
# Transaction ID                 #3474 192
# Date                           14-Oct-20
# Day of Week                    Wednesday
# Time                                   1
# Type of Card                  MasterCard
# Entry Mode                           PIN
# Amount                              £106
# Type of Transaction                  POS
# Merchant Group                   Fashion
# Country of Transaction            Russia
# Shipping Address                  Russia
# Country of Residence      United Kingdom
# Gender                                 F
# Age                                 48.7
# Bank                               Metro
# Fraud                                  1
# Name: 11, dtype: object
# Transaction ID                 #3328 082
# Date                           13-Oct-20
# Day of Week                      Tuesday
# Time                                  21
# Type of Card                  MasterCard
# Entry Mode                           PIN
# Amount                               £21
# Type of Transaction                  ATM
# Merchant Group                Restaurant
# Country of Transaction    United Kingdom
# Shipping Address          United Kingdom
# Country of Residence      United Kingdom
# Gender                                 M
# Age                                 43.6
# Bank                            Barclays
# Fraud                                  0
# Name: 12, dtype: object
# Transaction ID                 #3409 035
# Date                           13-Oct-20
# Day of Week                      Tuesday
# Time                                  20
# Type of Card                  MasterCard
# Entry Mode                           PIN
# Amount                              £211
# Type of Transaction                  ATM
# Merchant Group                      Food
# Country of Transaction    United Kingdom
# Shipping Address          United Kingdom
# Country of Residence      United Kingdom
# Gender                                 F
# Age                                 46.4
# Bank                                HSBC
# Fraud                                  0
# Name: 13, dtype: object
# Transaction ID                 #3261 845
# Date                           14-Oct-20
# Day of Week                    Wednesday
# Time                                  17
# Type of Card                  MasterCard
# Entry Mode                           PIN
# Amount                               £98
# Type of Transaction                  ATM
# Merchant Group                  Products
# Country of Transaction    United Kingdom
# Shipping Address          United Kingdom
# Country of Residence      United Kingdom
# Gender                                 F
# Age                                 37.2
# Bank                               Monzo
# Fraud                                  0
# Name: 15, dtype: object
# Transaction ID                 #3513 029
# Date                           13-Oct-20
# Day of Week                      Tuesday
# Time                                   0
# Type of Card                  MasterCard
# Entry Mode                           CVC
# Amount                               £25
# Type of Transaction               Online
# Merchant Group                      Food
# Country of Transaction            Russia
# Shipping Address                  Russia
# Country of Residence      United Kingdom
# Gender                                 M
# Age                                 54.3
# Bank                            Barlcays
# Fraud                                  1
# Name: 16, dtype: object
# Transaction ID                 #3521 688
# Date                           14-Oct-20
# Day of Week                    Wednesday
# Time                                  23
# Type of Card                  MasterCard
# Entry Mode                           Tap
# Amount                               £29
# Type of Transaction                  POS
# Merchant Group                  Products
# Country of Transaction             India
# Shipping Address                   India
# Country of Residence      United Kingdom
# Gender                                 F
# Age                                 55.0
# Bank                             Halifax
# Fraud                                  0
# Name: 19, dtype: object

# %%
# Fill missing values in the 'Type of Transaction' column with a placeholder
df['Type of Card'].fillna('Unknown', inplace=True)

# Filter top 2000 records
df_top_2000 = df.head(2000)

# Filter transactions with type of transaction 'Online'
card_transactions = df_top_2000[df_top_2000['Type of Card'] == 'Visa']
df_top_2000
# Out:
#      Transaction ID       Date Day of Week  Time Type of Card Entry Mode  \
# 0         #3577 209  14-Oct-20   Wednesday    19         Visa        Tap
# 1         #3039 221  14-Oct-20   Wednesday    17   MasterCard        PIN
# 2         #2694 780  14-Oct-20   Wednesday    14         Visa        Tap
# 3         #2640 960  13-Oct-20     Tuesday    14         Visa        Tap
# 4         #2771 031  13-Oct-20     Tuesday    23         Visa        CVC
# ...             ...        ...         ...   ...          ...        ...
# 1995      #2687 300  14-Oct-20   Wednesday    23   MasterCard        PIN
# 1996      #2867 705  14-Oct-20   Wednesday    23         Visa        PIN
# 1997      #2988 629  14-Oct-20   Wednesday    10         Visa        Tap
# 1998      #2635 065  14-Oct-20   Wednesday    19         Visa        PIN
# 1999      #3230 144  13-Oct-20     Tuesday    21         Visa        PIN
#
#      Amount Type of Transaction Merchant Group Country of Transaction  \
# 0        £5                 POS  Entertainment         United Kingdom
# 1      £288                 POS       Services                    USA
# 2        £5                 POS     Restaurant                  India
# 3       £28                 POS  Entertainment         United Kingdom
# 4       £91              Online    Electronics                    USA
# ...     ...                 ...            ...                    ...
# 1995    £21                 ATM       Products                  China
# 1996    £22                 ATM    Electronics         United Kingdom
# 1997     £9                 POS       Products         United Kingdom
# 1998    £22                 ATM   Subscription                    USA
# 1999   £230                 ATM         Gaming         United Kingdom
#
#      Shipping Address Country of Residence Gender   Age      Bank  Fraud
# 0      United Kingdom       United Kingdom      M  25.2       RBS      0
# 1                 USA                  USA      F  49.6    Lloyds      0
# 2               India                India      F  42.2  Barclays      0
# 3               India       United Kingdom      F  51.0  Barclays      0
# 4                 USA       United Kingdom      M  38.0   Halifax      1
# ...               ...                  ...    ...   ...       ...    ...
# 1995            China                China      F  39.6   Halifax      0
# 1996   United Kingdom       United Kingdom      M  47.1  Barlcays      0
# 1997   United Kingdom       United Kingdom      F  32.3  Barclays      0
# 1998   United Kingdom                  USA      F  58.6  Barclays      0
# 1999            India       United Kingdom      M  35.5       RBS      0
#
# [2000 rows x 16 columns]

# %%
# Vectorize the text data
vectorizer = TfidfVectorizer()
card_group_vectors = vectorizer.fit_transform(df_top_2000['Type of Card'])

# Calculate cosine similarity
cosine_sim = cosine_similarity(card_group_vectors, card_group_vectors)

# Get indices of 'Visa' transactions
card_indices = card_transactions.index

# Find similar transactions
similar_transactions = []
for idx in card_indices:
    similarity_scores = list(enumerate(cosine_sim[idx]))
    similarity_scores_sorted = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
    similar_indices = [x[0] for x in similarity_scores_sorted[1:11]]  # Exclude the transaction itself
    similar_transactions.extend(similar_indices)

# %%
# Remove duplicate indices and keep only unique ones
similar_transactions = list(set(similar_transactions))

# Print details of similar transactions
print("10 similar transactions based on the type of card 'Visa':")
for idx in similar_transactions:
    print(df_top_2000.iloc[idx])
# Out:
# 10 similar transactions based on the type of card 'Visa':
# Transaction ID             #2694 780
# Date                       14-Oct-20
# Day of Week                Wednesday
# Time                              14
# Type of Card                    Visa
# Entry Mode                       Tap
# Amount                            £5
# Type of Transaction              POS
# Merchant Group            Restaurant
# Country of Transaction         India
# Shipping Address               India
# Country of Residence           India
# Gender                             F
# Age                             42.2
# Bank                        Barclays
# Fraud                              0
# Name: 2, dtype: object
# Transaction ID                 #2640 960
# Date                           13-Oct-20
# Day of Week                      Tuesday
# Time                                  14
# Type of Card                        Visa
# Entry Mode                           Tap
# Amount                               £28
# Type of Transaction                  POS
# Merchant Group             Entertainment
# Country of Transaction    United Kingdom
# Shipping Address                   India
# Country of Residence      United Kingdom
# Gender                                 F
# Age                                 51.0
# Bank                            Barclays
# Fraud                                  0
# Name: 3, dtype: object
# Transaction ID                 #2771 031
# Date                           13-Oct-20
# Day of Week                      Tuesday
# Time                                  23
# Type of Card                        Visa
# Entry Mode                           CVC
# Amount                               £91
# Type of Transaction               Online
# Merchant Group               Electronics
# Country of Transaction               USA
# Shipping Address                     USA
# Country of Residence      United Kingdom
# Gender                                 M
# Age                                 38.0
# Bank                             Halifax
# Fraud                                  1
# Name: 4, dtype: object
# Transaction ID                 #3652 191
# Date                           13-Oct-20
# Day of Week                      Tuesday
# Time                                  18
# Type of Card                        Visa
# Entry Mode                           CVC
# Amount                              £231
# Type of Transaction               Online
# Merchant Group                  Children
# Country of Transaction    United Kingdom
# Shipping Address          United Kingdom
# Country of Residence      United Kingdom
# Gender                                 M
# Age                                 39.5
# Bank                            Barclays
# Fraud                                  0
# Name: 6, dtype: object
# Transaction ID                 #2667 502
# Date                           13-Oct-20
# Day of Week                      Tuesday
# Time                                  11
# Type of Card                        Visa
# Entry Mode                           PIN
# Amount                              £326
# Type of Transaction                  ATM
# Merchant Group                  Children
# Country of Transaction    United Kingdom
# Shipping Address          United Kingdom
# Country of Residence      United Kingdom
# Gender                                 F
# Age                                 54.8
# Bank                               Metro
# Fraud                                  0
# Name: 10, dtype: object
# Transaction ID                 #2605 734
# Date                           13-Oct-20
# Day of Week                      Tuesday
# Time                                  11
# Type of Card                        Visa
# Entry Mode                           Tap
# Amount                               £28
# Type of Transaction                  POS
# Merchant Group             Entertainment
# Country of Transaction    United Kingdom
# Shipping Address                   China
# Country of Residence      United Kingdom
# Gender                                 F
# Age                                 50.6
# Bank                               Metro
# Fraud                                  0
# Name: 14, dtype: object
# Transaction ID                 #3173 400
# Date                           14-Oct-20
# Day of Week                    Wednesday
# Time                                  21
# Type of Card                        Visa
# Entry Mode                           CVC
# Amount                              £242
# Type of Transaction               Online
# Merchant Group                  Services
# Country of Transaction    United Kingdom
# Shipping Address          United Kingdom
# Country of Residence      United Kingdom
# Gender                                 M
# Age                                 62.0
# Bank                            Barlcays
# Fraud                                  0
# Name: 17, dtype: object
# Transaction ID                 #2688 254
# Date                           13-Oct-20
# Day of Week                      Tuesday
# Time                                  20
# Type of Card                        Visa
# Entry Mode                           PIN
# Amount                               £22
# Type of Transaction                  ATM
# Merchant Group                  Children
# Country of Transaction    United Kingdom
# Shipping Address          United Kingdom
# Country of Residence      United Kingdom
# Gender                                 M
# Age                                 28.5
# Bank                              Lloyds
# Fraud                                  0
# Name: 18, dtype: object
# Transaction ID                 #2624 152
# Date                           13-Oct-20
# Day of Week                      Tuesday
# Time                                   8
# Type of Card                        Visa
# Entry Mode                           CVC
# Amount                              £397
# Type of Transaction               Online
# Merchant Group               Electronics
# Country of Transaction    United Kingdom
# Shipping Address          United Kingdom
# Country of Residence      United Kingdom
# Gender                                 F
# Age                                 29.9
# Bank                            Barclays
# Fraud                                  0
# Name: 20, dtype: object
# Transaction ID            #3498 300
# Date                      13-Oct-20
# Day of Week                 Tuesday
# Time                             19
# Type of Card                   Visa
# Entry Mode                      CVC
# Amount                          £38
# Type of Transaction          Online
# Merchant Group                 Food
# Country of Transaction       Russia
# Shipping Address             Russia
# Country of Residence         Russia
# Gender                            M
# Age                            80.5
# Bank                       Barlcays
# Fraud                             0
# Name: 21, dtype: object
